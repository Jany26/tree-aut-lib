# %%
from jupyter import *
from test_data import *

# %%
for box in boxesDict.values():
    dot = createDOTfromTA(box)
    dot
print(dot)
dot
# Out:
# // Tree Automaton prefix(boxH1, [Port_H0,0])
# digraph {
# 	u2 [shape=circle]
# 	u0 [shape=circle]
# 	"->u0" [label="" height=0.001 shape=point width=0.001]
# 	"->u0" -> u0 [arrowsize=0.5 penwidth=2.0]
# 	u1 [shape=circle]
# 	"u0-LH->u0u2" [label="" height=0.05 shape=point width=0.05]
# 	u0 -> "u0-LH->u0u2" [arrowhead=empty overlap=false penwidth=1.0 splines=true]
# 	"u0-LH->u0u2" -> u0 [label="LH:0" arrowhead=vee arrowsize=0.5 penwidth=1.0]
# 	"u0-LH->u0u2" -> u2 [label="LH:1" arrowhead=vee arrowsize=0.5 penwidth=1.0]
# 	"u0-LH->u1u2" [label="" height=0.05 shape=point width=0.05]
# 	u0 -> "u0-LH->u1u2" [arrowhead=empty overlap=false penwidth=1.0 splines=true]
# 	"u0-LH->u1u2" -> u1 [label="LH:0" arrowhead=vee arrowsize=0.5 penwidth=1.0]
# 	"u0-LH->u1u2" -> u2 [label="LH:1" arrowhead=vee arrowsize=0.5 penwidth=1.0]
# 	"u0-Port_H0->" [height=0.001 shape=point width=0.001]
# 	u0 -> "u0-Port_H0->" [label=Port_H0 arrowsize=0.5 penwidth=2.0]
# ...

# %%
vtfBox = createDOTfromFile("../nta/vtf/A0053.vtf")
print(vtfBox)
vtfBox
# Out:
# // Tree Automaton A0053
# digraph {
# 	q12 [shape=circle]
# 	q39 [shape=circle]
# 	q50 [shape=circle]
# 	q22 [shape=circle]
# 	q2 [shape=circle]
# 	q46 [shape=circle]
# 	q35 [shape=circle]
# 	q36 [shape=circle]
# 	q47 [shape=circle]
# 	"->q47" [label="" height=0.001 shape=point width=0.001]
# 	"->q47" -> q47 [arrowsize=0.5 penwidth=2.0]
# 	q7 [shape=circle]
# 	q42 [shape=circle]
# 	q31 [shape=circle]
# 	q5 [shape=circle]
# 	"->q5" [label="" height=0.001 shape=point width=0.001]
# 	"->q5" -> q5 [arrowsize=0.5 penwidth=2.0]
# 	q10 [shape=circle]
# 	q4 [shape=circle]
# 	q40 [shape=circle]
# 	q51 [shape=circle]
# 	q0 [shape=circle]
# 	q26 [shape=circle]
# 	q33 [shape=circle]
# 	q6 [shape=circle]
# 	q28 [shape=circle]
# 	q8 [shape=circle]
# 	q1 [shape=circle]
# 	q30 [shape=circle]
# 	q21 [shape=circle]
# 	q37 [shape=circle]
# 	q24 [shape=circle]
# 	q27 [shape=circle]
# 	q52 [shape=circle]
# 	q32 [shape=circle]
# 	q11 [shape=circle]
# 	q43 [shape=circle]
# 	q23 [shape=circle]
# ...
